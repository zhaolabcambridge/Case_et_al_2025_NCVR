# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
adata = sc.read_h5ad('../data/aa_aligned_adata_sc.h5ad')

# %%
sc.tl.umap(adata, min_dist = 0.3, init_pos='random', random_state=69)
# Out:
# /Users/james/miniconda3/envs/lilacs/lib/python3.10/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/james/miniconda3/envs/lilacs/lib/python3.10/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
del adata.uns['fine_clustering_colors']

# %%
sc.pl.umap(adata, color='fine_clustering', frameon=False,
           palette={
                "CD4_Treg":"#74A1C6",
                "CD4_Tem":"#B65BCD",
                "CD4_Tcm":"#E55C5C",
                "CD4_Th2":"#F3803E",
                "CD8_Temra":"#FFBAEA",
                "CD8_Tem":"#B18DBA",
                "CD4_Tnaive":"#5AB67E",
                "CD8_Tnaive":"#4C725B",
           })
# Out:
# /Users/james/miniconda3/envs/lilacs/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
